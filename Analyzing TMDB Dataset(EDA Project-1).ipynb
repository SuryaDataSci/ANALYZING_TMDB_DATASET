# %%
#importing the necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset for analyzing the dataset
data=pd.read_csv(r'C:\Users\VENKATA SURYA\OneDrive\Desktop\everything about ai and ds\tmdb_movies_data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
data.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
data.tail(3)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  ...  \
# 10863    Eldar Ryazanov                                           NaN  ...
# 10864       Woody Allen                     WOODY ALLEN STRIKES BACK!  ...
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!  ...
#
# ...

# %%
#describing i.e taking statistical apperance of dataset
data.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
#dataset has null values so try to figure it out
data.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
#now filling the null values with fillna function
data.fillna(0)
print()

# %%
#now removing duplicate rows
sum(data.duplicated())
# Out:
# 1

# %%
#now droping the duplicate rows
data.drop_duplicates(inplace=True)
print("after process completion",data.shape)
# Out:
# after process completion (10865, 21)

# %%
#now checking the movies relaease time in the dataset to analyze further trend.
data['release_date']=pd.to_datetime(data['release_date'])
data['release_date'].head()
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# 3   2015-12-15
# 4   2015-04-01
# Name: release_date, dtype: datetime64[ns]

# %%
#now we remove the unused column for the above dataset.
data.drop(['budget_adj','revenue_adj','overview','imdb_id','homepage','tagline'],axis =1,inplace = True)
print("Afetr Removing Unused Columns (Rows,Columns) : ",data.shape)
# Out:
# Afetr Removing Unused Columns (Rows,Columns) :  (10865, 15)

# %%
#now drop the rows of unappropriate values
print("rows with zero values:",data[(data['budget']==0)].shape[0])
print("rows with zero in reverse:",data[(data['revenue']==0)].shape[0])
# Out:
# rows with zero values: 5696
# rows with zero in reverse: 6016

# %%
#eda processes start
#now first finding the highest release of movies.
dd=data.groupby('release_year').count()['id']
print(dd.tail())
data.groupby('release_year').count()['id'].plot(xticks = np.arange(1960,2016,5))
sns.set(rc={'figure.figsize':(10,5)})
plt.title("year with high releases",fontsize=14)
plt.xlabel('release of year',fontsize=13)
plt.ylabel('number of movies',fontsize=13)
sns.set_style("whitegrid")
# Out:
# release_year
# 2011    540
# 2012    588
# 2013    659
# 2014    700
# 2015    629
# Name: id, dtype: int64

# %%
#calculate todays profit
data['Profit']=data['revenue']-data['budget']

# %%
#now we will findout the movies with highest and lowest profut
def find_minmax(x):
    min_index=data[x].idxmin()
    high_index=data[x].idxmax()
    high=pd.DataFrame(data.loc[high_index,:])
    low=pd.DataFrame(data.loc[min_index,:])
    print("movie with highest profit"+ x + ":",data['original_title'][high_index])
    print("movie with lowest profit"+ x + ":",data['original_title'][min_index])
    return pd.concat([high,low],axis=1)
find_minmax('Profit')
# Out:
# movie with highest profitProfit: Avatar
# movie with lowest profitProfit: The Warrior's Way
#                                                                    1386  \
# id                                                                19995
# popularity                                                     9.432768
# budget                                                        237000000
# revenue                                                      2781505847
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# keywords              culture clash|future|space war|space colony|so...
# runtime                                                             162
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# ...

# %%
#now plotting the graph foe most succesful and high profit movies
info=pd.DataFrame(data['Profit'].sort_values(ascending = False))
info['original_title']=data['original_title']
dd=list(map(str,(info['original_title'])))
x=list(dd[:10])
y=list(info['Profit'][:10])

ax=sns.pointplot(x=y,y=x)
sns.set(rc={'figure.figsize':(10,5)})
ax.set_title("most profitable movies",fontsize=15)
ax.set_xlabel("Profit",fontsize=13)
sns.set_style("darkgrid")

# %%
#which year has highest prift rate combined
data.groupby('release_year')['Profit'].mean().plot()
plt.title("year with most profit",fontsize=14)
plt.xlabel('Release year',fontsize=13)
plt.ylabel('Average Profit',fontsize=13)
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style("whitegrid")

# %%
#relation between audience and movies of their popularity
data.groupby('runtime')['popularity'].mean().plot(figsize = (13,5),xticks=np.arange(0,1000,100))

plt.title("movies reached by popularity",fontsize=14)
plt.xlabel('Runtime',fontsize=13)
plt.ylabel('Average Popularity',fontsize=13)
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style("whitegrid")

# %%
ax = sns.regplot(x=data['revenue'], y=data['budget'],color='c')
ax.set_title("Revenue Vs Budget",fontsize=13)
ax.set_xlabel("Revenue",fontsize=12)
ax.set_ylabel("Budget",fontsize=12)
sns.set(rc={'figure.figsize':(6,4)})
sns.set_style("whitegrid")

#find the correlation between them
data['budget'] = data['budget'].replace(0,np.NAN)
data['revenue'] = data['revenue'].replace(0,np.NAN)
data['Profit'] = data['Profit'].replace(0,np.NAN)
data_corr = data.corr()
print("Correlation Between Revenue And Budget : ",data_corr.loc['revenue','budget'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 12
#      10 data['revenue'] = data['revenue'].replace(0,np.NAN)
#      11 data['Profit'] = data['Profit'].replace(0,np.NAN)
# ---> 12 data_corr = data.corr()
#      13 print("Correlation Between Revenue And Budget : ",data_corr.loc['revenue','budget'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
# ...

# %%
#checking the average ratings of every movie
ax = sns.regplot(x=data['release_year'], y=data['vote_average'],color='c')
ax.set_title("Release Year Vs Vote Average",fontsize=13)
ax.set_xlabel("Release Year",fontsize=12)
ax.set_ylabel("Vote Average",fontsize=12)
sns.set(rc={'figure.figsize':(6,4)})
sns.set_style("whitegrid")
print("Correlation Between Release Year And Vote Average : ",data_corr.loc['release_year','vote_average'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       6 sns.set(rc={'figure.figsize':(6,4)})
#       7 sns.set_style("whitegrid")
# ----> 8 print("Correlation Between Release Year And Vote Average : ",data_corr.loc['release_year','vote_average'])
#
# NameError: name 'data_corr' is not defined

# %%
#now which month has produced many movies with good gross profit
month_release = data['release_date'].dt.month
number_of_release = month_release.value_counts().sort_index()
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
number_of_release = pd.DataFrame(number_of_release)
number_of_release['month'] = months
number_of_release.rename(columns = {'release_date':'number_of_release'},inplace=True)
number_of_release.plot(x='month',kind='bar',fontsize = 11,figsize=(8,6))
plt.title('Months vs Number Of Movie Releases',fontsize = 15)
plt.xlabel('Month',fontsize = 13)
plt.ylabel('Number of movie releases',fontsize = 13)
sns.set_style("darkgrid")

# %%
#now building and checking the relation between genre and month of movie that suits
def count_genre(x):
    data_plot = data[x].str.cat(sep = '|')
    dd = pd.Series(data_plot.split('|'))
    info = dd.value_counts(ascending=False)
    return info
total_genre_movies = count_genre('genres')
total_genre_movies.plot(kind= 'barh',figsize = (13,6),fontsize=12,colormap='tab20c')
plt.title("Genre With Highest Release",fontsize=15)
plt.xlabel('Number Of Movies',fontsize=13)
plt.ylabel("Genres",fontsize= 13)
sns.set_style("whitegrid")

# %%
#now checking which genre has highest rated for a moviw to be based
i = 0
genre_count = []
for genre in total_genre_movies.index:
    genre_count.append([genre, total_genre_movies[i]])
    i = i+1
    
plt.rc('font', weight='bold')
f, ax = plt.subplots(figsize=(5, 5))
genre_count.sort(key = lambda x:x[1], reverse = True)
labels, sizes = zip(*genre_count)
labels_selected = [n if v > sum(sizes) * 0.01 else '' for n, v in genre_count]
ax.pie(sizes, labels=labels_selected,
       autopct = lambda x:'{:2.0f}%'.format(x) if x > 1 else '',
       shadow=False, startangle=0)
ax.axis('equal')
plt.tight_layout()

# %%
#which genre suits which actor relation
count_actor_flims = count_genre('cast')
count_actor_flims.iloc[:20].plot.bar(figsize=(13,6),colormap= 'tab20c',fontsize=12)
plt.title("Most Frequent Actor",fontsize=15)
plt.xticks(rotation = 70)
plt.xlabel('Actor',fontsize=13)
plt.ylabel("Number Of Movies",fontsize= 13)
sns.set_style("whitegrid")

# %%
#top companies with most amount of releases of movies
production_companies = count_genre('production_companies')
production_companies.iloc[:20].plot(kind='barh',figsize=(16,8),fontsize=13)
plt.title("Production Companies Vs Number Of Movies",fontsize=15)
plt.xlabel('Number Of Movies',fontsize=14)
sns.set_style("whitegrid")

# %%
#which director of the product companies mainly relaese more movies
count_director_movies = count_genre('director')
count_director_movies.iloc[:20].plot(kind='bar',figsize=(13,6),fontsize=12)
plt.title("Director Vs Number Of Movies",fontsize=15)
plt.xticks(rotation=70)
plt.ylabel("Number Of Movies",fontsize= 13)
sns.set_style("whitegrid")

# %%
#now finally releaisng the revenue and buildong a structural report of the data
info = pd.DataFrame(data['revenue'].sort_values(ascending=False))
data_set = ['id','popularity','budget','original_title','cast','director','runtime','genres','vote_average','release_year']
for i in data_set:
    info[i] = data[i]
info.head(3)
# Out:
#            revenue      id  popularity       budget  \
# 1386  2.781506e+09   19995    9.432768  237000000.0
# 3     2.068178e+09  140607   11.173104  200000000.0
# 5231  1.845034e+09     597    4.355219  200000000.0
#
#                     original_title  \
# 1386                        Avatar
# 3     Star Wars: The Force Awakens
# 5231                       Titanic
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...    J.J. Abrams
# 5231  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...  James Cameron
#
#       runtime                                    genres  vote_average  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction           7.1
# 3         136  Action|Adventure|Science Fiction|Fantasy           7.5
# 5231      194                    Drama|Romance|Thriller           7.3
#
#       release_year
# ...

# %%
fig, axes = plt.subplots(2,2,figsize = (16,6))
fig.suptitle("Revenue Vs (Budget,Popularity,Vote Average,Runtime)",fontsize=14)
sns.regplot(x=data['revenue'], y=data['budget'],color='c',ax=axes[0][0])
sns.regplot(x=data['revenue'], y=data['popularity'],color='c',ax=axes[0][1])
sns.regplot(x=data['revenue'], y=data['vote_average'],color='c',ax=axes[1][0])
sns.regplot(x=data['revenue'], y=data['runtime'],color='c',ax=axes[1][1])
sns.set_style("whitegrid")

# %%
'''
Conclusion of the project:
-->Drama is the most popular genre, followed by Action, Comedy, and Thriller.
-->'Avatar,' 'Star Wars,' and 'Titanic' are the most profitable movies.
-->Maximum number of movies were released in the year 2014.
-->Warner Bros, Universal Pictures, and Paramount Pictures are the top production companies with the highest lifetime profits.
-->Revenue is directly connected to the budget, with higher budgets showing a corresponding increase in revenues.
'''
# Out:
# "\nConclusion of the project:\n-->Drama is the most popular genre, followed by Action, Comedy, and Thriller.\n-->'Avatar,' 'Star Wars,' and 'Titanic' are the most profitable movies.\n-->Maximum number of movies were released in the year 2014.\n-->Warner Bros, Universal Pictures, and Paramount Pictures are the top production companies with the highest lifetime profits.\n-->Revenue is directly connected to the budget, with higher budgets showing a corresponding increase in revenues.\n"
